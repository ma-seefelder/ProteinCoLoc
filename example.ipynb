# %%
using BenchmarkTools
using .ProteinCoLoc
# Out:
# UndefVarError: `ProteinCoLoc` not defined
#
#
#
# Stacktrace:
#
#   [1] eval
#
#     @ .\boot.jl:385 [inlined]
#
#   [2] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base .\loading.jl:2076
#
#   [3] #invokelatest#2
#
#     @ .\essentials.jl:892 [inlined]
#
#   [4] invokelatest
#
#     @ .\essentials.jl:889 [inlined]
#
#   [5] (::VSCodeServer.var"#214#215"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer c:\Users\manue\.vscode-insiders\extensions\julialang.language-julia-1.75.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:19
#
#   [6] withpath(f::VSCodeServer.var"#214#215"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
#     @ VSCodeServer c:\Users\manue\.vscode-insiders\extensions\julialang.language-julia-1.75.2\scripts\packages\VSCodeServer\src\repl.jl:274
#
# ...

# %% [markdown]
# ## Define folder locations
#
# - image_path: Path to folder where the images of each individual channel of the sample are stored
# - control_image_path: Path to folder where the images of each individual channel of the reference / control are stored
# - output_folder_path: Path to folder where the results will be stored.

# %%
image_path = "C:/Users/manue/Desktop/benchmark/positive"
control_image_path = "C:/Users/manue/Desktop/benchmark/negative"
output_folder_path = "C:/Users/manue/Desktop/benchmark/result/"

# %% [markdown]
# ## Define other variables / arguments.
# For more details on the meaning of all arguments to ProteinCoLoc.start_anaylsis ?ProteinCoLoc.start_analysis

# %%
number_patches = 16
number_patches_loc = 200
number_channels = 3
channel_selection = true
channel_selection_two = [2,3] 
patched_correlation_plt = true
local_correlation_plt = true 
bayes_factor_plt = true 
bayes_range_plt = true 
posterior_plt = true
mask_plt = true
